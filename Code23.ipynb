# %%
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
    """Given 2 numbers a and b this tool returns their product"""
    return a*b

# %%
print(multiply.invoke({'a':3, 'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding
from decouple import config
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

api_key=config("OPEN_ROUTER_API_KEY")

llm=ChatOpenAI(
    model="openrouter/owl-alpha",

    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
)

# %%
llm_with_tools=llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Hi how are you?')
# Out:
# AIMessage(content="Hello! I'm OWL, nice to meet you! I'm doing well, thank you for asking. How can I help you today? Is there anything specific you'd like to work on or any questions I can assist with? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 49, 'prompt_tokens': 251, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0, 'upstream_inference_prompt_cost': 0, 'upstream_inference_completions_cost': 0}}, 'model_provider': 'openai', 'model_name': 'openrouter/owl-alpha', 'system_fingerprint': None, 'id': 'gen-1782303828-1OtEE7NjEo4ZsTIy2rhW', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ef995-1e26-7561-9d23-40e7f9389dea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 251, 'output_tokens': 49, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
query = HumanMessage("'can you multiply 3 with 1000'")

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content="'can you multiply 3 with 1000'", additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)

# %%
messages.append(result)

# %%
result.tool_calls[0]['args']
# Out:
# {'a': 3, 'b': 1000}

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content="'can you multiply 3 with 1000'", additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 259, 'total_tokens': 285, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0, 'upstream_inference_prompt_cost': 0, 'upstream_inference_completions_cost': 0}}, 'model_provider': 'openai', 'model_name': 'openrouter/owl-alpha', 'system_fingerprint': None, 'id': 'gen-1782304800-cVUPrQmQLe3H4vgsFosG', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ef9a4-09e2-7ea0-95ab-7adf1e45bc83-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': '20d31d36-30aa-48fd-ab02-cab6b6d89661', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 259, 'output_tokens': 26, 'total_tokens': 285, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='3000', name='multiply', tool_call_id='20d31d36-30aa-48fd-ab02-cab6b6d89661')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The result of multiplying 3 with 1000 is 3000.'
