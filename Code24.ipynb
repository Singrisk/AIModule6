# %%
from langchain_core.tools import tool
import requests

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')
# Out:
# C:\Users\rahul.singh1\AppData\Local\Temp\ipykernel_11544\1123104826.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
results
# Out:
# "7 hours ago - Indian markets are overflowing with jamun this summer and a viral thread linked it to a grandmother's warning about drought. The science is more nuanced than that. Actor Samantha confirmed that she and husband Raj Nidimoru are expecting their ... The View From India Looking at World Affairs from the Indian perspective. SEE ALL NEWSLETTERS States Cities ... First Day First Show News and reviews from the world of cinema and streaming. SEE ALL NEWSLETTERS ... Opinion Editorial Cartoon Columns Comment Interview Lead Letters Open Page Corrections & Clarifications ... Today's Cache Your download of the top 5 technology stories of the day. 6 hours ago - Weather Today, Rain Alert Live Updates: Thunderstorms in Delhi cause significant temperature drop and relief from heat, says IMD. Lucknow Fire: In Lucknow, teams of the Lucknow Development Authority (LDA), the fire department and the electricity department continued inspections of educational institutions and commercial establishments. India, EU described the discussions as meaningful, free and frank, highlighting the value of maintaining regular engagement on human rights issues. 9 hours ago - Govt merges medicine price, complaint portals into single citizen platform · 'Wife searching for her husband': Udhyanidhi Stalin takes personal dig at Vijay, TVK fires back · 'Attempt to deflect': India snubs Khawaja Asif's 'will go to war ... 15 hours ago - eBooks TH Games Newsletter Lit For Life The Huddle ... There is no clarity as to how many workers were working at the site when accident occurred on June 24 afternoon; Chief Minister Suvendu Adhikari said that most of the workers were brought to work at the site from Bihar ... Sign in to unlock member-only benefits! ... Looks like you are already logged in from more than 5 devices!"

# %%
# tool binding
from decouple import config
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

api_key=config("OPEN_ROUTER_API_KEY")

llm=ChatOpenAI(
    model="openrouter/owl-alpha",

    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
)

# %%
llm.invoke('hi')
# Out:
# AIMessage(content='Hi there! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 102, 'total_tokens': 113, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0, 'upstream_inference_prompt_cost': 0, 'upstream_inference_completions_cost': 0}}, 'model_provider': 'openai', 'model_name': 'openrouter/owl-alpha', 'system_fingerprint': None, 'id': 'gen-1782366222-ANBS8q9QnwBVnmVX7nR8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019efd4d-408b-7b90-a7e5-d3070ec6cb09-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 102, 'output_tokens': 11, 'total_tokens': 113, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.agents import create_agent
from langchain import hub
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.agents import create_agent
#       2 from langchain import hub
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langchain\agents\__init__.py:3
#       1 """Entrypoint to building [Agents](https://docs.langchain.com/oss/python/langchain/agents) with LangChain."""  # noqa: E501
# ----> 3 from langchain.agents.factory import create_agent
#       4 from langchain.agents.middleware.types import AgentState
#       6 __all__ = [
#       7     "AgentState",
#       8     "create_agent",
#       9 ]
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langchain\agents\factory.py:23
#      21 from langchain_core.messages import AIMessage, AnyMessage, SystemMessage, ToolMessage
#      22 from langchain_core.tools import BaseTool
# ---> 23 from langgraph._internal._runnable import RunnableCallable
#      24 from langgraph.constants import END, START
#      25 from langgraph.graph.state import StateGraph
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:46
#      43 from langchain_core.tracers.langchain import LangChainTracer
#      44 from langgraph.store.base import BaseStore
# ---> 46 from langgraph._internal._config import (
#      47     ensure_config,
#      48     get_async_callback_manager_for_config,
#      49     get_callback_manager_for_config,
#      50     patch_config,
#      51 )
#      52 from langgraph._internal._constants import (
#      53     CONF,
#      54     CONFIG_KEY_NODE_ERROR,
#      55     CONFIG_KEY_RUNTIME,
#      56 )
#      57 from langgraph._internal._typing import MISSING
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langgraph\_internal\_config.py:20
#      14 from langchain_core.runnables import RunnableConfig
#      15 from langchain_core.runnables.config import (
#      16     CONFIG_KEYS,
#      17     COPIABLE_KEYS,
#      18     var_child_runnable_config,
#      19 )
# ---> 20 from langgraph.checkpoint.base import CheckpointMetadata
#      22 from langgraph._internal._constants import (
#      23     _CHECKPOINT_COORDINATE_KEYS,
#      24     CONF,
#    (...)     29     NS_SEP,
#      30 )
#      32 DEFAULT_RECURSION_LIMIT = int(getenv("LANGGRAPH_DEFAULT_RECURSION_LIMIT", "10007"))
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langgraph\checkpoint\base\__init__.py:20
#      18 from langgraph.checkpoint.base.id import uuid6
#      19 from langgraph.checkpoint.serde.base import SerializerProtocol, maybe_add_typed_methods
# ---> 20 from langgraph.checkpoint.serde.encrypted import EncryptedSerializer
#      21 from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
#      22 from langgraph.checkpoint.serde.types import (
#      23     ERROR,
#      24     INTERRUPT,
#    (...)     27     ChannelProtocol,
#      28 )
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5
#       2 from typing import Any
#       4 from langgraph.checkpoint.serde.base import CipherProtocol, SerializerProtocol
# ----> 5 from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
#       8 class EncryptedSerializer(SerializerProtocol):
#       9     """Serializer that encrypts and decrypts data using an encryption protocol."""
#
# File d:\Rahul Work\PythonModule6\.venv\Lib\site-packages\langgraph\checkpoint\serde\jsonplus.py:850
#     845     def __init__(self, message: str):
#     846         self.message = message
#     849 _option = (
# --> 850     ormsgpack.OPT_NON_STR_KEYS
#     851     | ormsgpack.OPT_PASSTHROUGH_DATACLASS
#     852     | ormsgpack.OPT_PASSTHROUGH_DATETIME
#     853     | ormsgpack.OPT_PASSTHROUGH_ENUM
#     854     | ormsgpack.OPT_PASSTHROUGH_UUID
#     855     | ormsgpack.OPT_REPLACE_SURROGATES
#     856 )
#     859 def _msgpack_enc(data: Any) -> bytes:
#     860     return ormsgpack.packb(data, default=_msgpack_default, option=_option)
#
# AttributeError: module 'ormsgpack' has no attribute 'OPT_NON_STR_KEYS'

# %%
import sys
print(sys.executable)
# Out:
# d:\Rahul Work\PythonModule6\.venv\Scripts\python.exe

# %%
# Step 2: Pull the ReAct prompt from LangChain Hub
prompt = hub.pull("hwchase17/react") # pulls the standard ReAct agent prompt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Step 2: Pull the ReAct prompt from LangChain Hub
# ----> 2 prompt = langchainhub.pull("hwchase17/react") # pulls the standard ReAct agent prompt
#
# AttributeError: module 'langchainhub' has no attribute 'pull'

# %%
# Step 3: Create the ReAct agent manually with the pulled prompt
agent = create_agent(
    llm=llm,
    tools=[search_tool],
    system_prompt=prompt
)

# %%
# Step 5: Invoke
response = agent.invoke({"input": "give a 5 pointer preview for today's IPL match between CSK and PBKS"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Step 5: Invoke
# ----> 2 response = agent.invoke({"input": "give a 5 pointer preview for today's IPL match between CSK and PBKS"})
#       3 print(response)
#
# NameError: name 'agent' is not defined

# %%
response['output']
