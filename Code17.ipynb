# %%
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
embedding_function = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-2",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

# Create LangChain documents for IPL players
doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsman in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
    metadata={"team": "Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to mulitple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Chennai Super Kings"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

vector_store = Chroma(
    embedding_function=embedding_function,
    persist_directory= 'chroma_db',
    collection_name='sample'
)

# %%
vector_store.add_documents(docs)

vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['53196095-3cc0-4698-baa5-16f60d50bdfa',
#   'b3ff9a4b-2037-4bee-89b9-886540540345',
#   '04462f81-d809-40a7-9382-06c3e983b331',
#   '23171309-1876-4b9a-99a0-3f9294c837e8',
#   '7dcf8286-c554-430c-aab3-e8840a35a9bf'],
#  'embeddings': array([[ 0.00671709,  0.01044892,  0.01184239, ...,  0.00212552,
#           0.01096096,  0.00292906],
#         [ 0.00578349,  0.03275334, -0.00712996, ...,  0.00599   ,
#           0.00842474,  0.01284763],
#         [ 0.002831  ,  0.02550364, -0.00729155, ..., -0.00493593,
#           0.01493757,  0.01091656],
#         [ 0.03408059,  0.01119854, -0.01184934, ...,  0.00848975,
#           0.02335239, -0.0077354 ],
#         [-0.00296271,  0.01466555, -0.01345706, ...,  0.00715038,
#           0.01247527,  0.00910379]], shape=(5, 3072)),
# ...

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='23171309-1876-4b9a-99a0-3f9294c837e8', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='7dcf8286-c554-430c-aab3-e8840a35a9bf', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='23171309-1876-4b9a-99a0-3f9294c837e8', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.6193535327911377),
#  (Document(id='7dcf8286-c554-430c-aab3-e8840a35a9bf', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.6677330136299133)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query=" ",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='7dcf8286-c554-430c-aab3-e8840a35a9bf', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.6848995685577393),
#  (Document(id='04462f81-d809-40a7-9382-06c3e983b331', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to mulitple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.7264091968536377)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistency. ",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='53196095-3cc0-4698-baa5-16f60d50bdfa', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['53196095-3cc0-4698-baa5-16f60d50bdfa',
#   'b3ff9a4b-2037-4bee-89b9-886540540345',
#   '04462f81-d809-40a7-9382-06c3e983b331',
#   '23171309-1876-4b9a-99a0-3f9294c837e8',
#   '7dcf8286-c554-430c-aab3-e8840a35a9bf'],
#  'embeddings': array([[ 0.01867363,  0.01626323,  0.00489267, ...,  0.00217575,
#           0.0087269 ,  0.00323244],
#         [ 0.00578349,  0.03275334, -0.00712996, ...,  0.00599   ,
#           0.00842474,  0.01284763],
#         [ 0.002831  ,  0.02550364, -0.00729155, ..., -0.00493593,
#           0.01493757,  0.01091656],
#         [ 0.03408059,  0.01119854, -0.01184934, ...,  0.00848975,
#           0.02335239, -0.0077354 ],
#         [-0.00296271,  0.01466555, -0.01345706, ...,  0.00715038,
#           0.01247527,  0.00910379]], shape=(5, 3072)),
#  'documents': ['Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistency. ',
# ...

# %%
# delete document
vector_store.delete(ids=['53196095-3cc0-4698-baa5-16f60d50bdfa'])

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['b3ff9a4b-2037-4bee-89b9-886540540345',
#   '04462f81-d809-40a7-9382-06c3e983b331',
#   '23171309-1876-4b9a-99a0-3f9294c837e8',
#   '7dcf8286-c554-430c-aab3-e8840a35a9bf'],
#  'embeddings': array([[ 0.00578349,  0.03275334, -0.00712996, ...,  0.00599   ,
#           0.00842474,  0.01284763],
#         [ 0.002831  ,  0.02550364, -0.00729155, ..., -0.00493593,
#           0.01493757,  0.01091656],
#         [ 0.03408059,  0.01119854, -0.01184934, ...,  0.00848975,
#           0.02335239, -0.0077354 ],
#         [-0.00296271,  0.01466555, -0.01345706, ...,  0.00715038,
#           0.01247527,  0.00910379]], shape=(4, 3072)),
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
# ...
